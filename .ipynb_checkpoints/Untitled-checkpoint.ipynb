# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("books_with_emotion.csv")

# %%
dataset.head()
# Out:
#           isbn13      isbn10                title  \
# 0  9780002005883  0002005883               Gilead
# 1  9780002261982  0002261987         Spider's Web
# 2  9780006178736  0006178731       Rage of angels
# 3  9780006280897  0006280897       The Four Loves
# 4  9780006280934  0006280935  The Problem of Pain
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2                   Sidney Sheldon                        Fiction
# 3              Clive Staples Lewis                 Christian life
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=FKo2T...
# ...

# %%
dataset.sample()
# Out:
#              isbn13      isbn10                title           authors  \
# 3376  9780743284882  0743284887  Chuck Klosterman IV  Chuck Klosterman
#
#                      categories  \
# 3376  Biography & Autobiography
#
#                                               thumbnail  \
# 3376  http://books.google.com/books/content?id=z8Zb3...
#
#                                             description  published_year  \
# 3376  A collection by the pop culture commentator in...          2006.0
#
#       average_rating  num_pages  ...  \
# 3376            3.85      374.0  ...
#
#                                      title_and_subtitle  \
# 3376  Chuck Klosterman IV: A Decade of Curious Peopl...
#
#                                      tagged_description simple_categories  \
# 3376  9780743284882 A collection by the pop culture ...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# ...

# %%
dataset.describe()
# Out:
#              isbn13  published_year  average_rating    num_pages  \
# count  5.230000e+03     5228.000000     5198.000000  5198.000000
# mean   9.780668e+12     1999.841431        3.922205   348.417468
# std    6.022625e+08        9.076272        0.324957   229.903414
# min    9.780002e+12     1876.000000        0.000000     0.000000
# 25%    9.780313e+12     1998.000000        3.750000   213.000000
# 50%    9.780521e+12     2002.000000        3.940000   312.000000
# 75%    9.780807e+12     2005.000000        4.120000   416.000000
# max    9.789028e+12     2019.000000        5.000000  3342.000000
#
#        ratings_count        anger      disgust         fear          joy  \
# count   5.198000e+03  5230.000000  5230.000000  5230.000000  5230.000000
# mean    2.112707e+04     0.165170     0.201070     0.309483     0.281273
# std     1.446344e+05     0.219034     0.213302     0.342726     0.318262
# min     0.000000e+00     0.000606     0.000821     0.000442     0.000550
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5230 entries, 0 to 5229
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   isbn13              5230 non-null   int64
#  1   isbn10              5230 non-null   object
#  2   title               5230 non-null   object
#  3   authors             5198 non-null   object
#  4   categories          5198 non-null   object
#  5   thumbnail           5061 non-null   object
#  6   description         5230 non-null   object
#  7   published_year      5228 non-null   float64
#  8   average_rating      5198 non-null   float64
#  9   num_pages           5198 non-null   float64
#  10  ratings_count       5198 non-null   float64
#  11  title_and_subtitle  5230 non-null   object
#  12  tagged_description  5230 non-null   object
#  13  simple_categories   5230 non-null   object
#  14  anger               5230 non-null   float64
# ...

# %%
dataset.drop(["isbn13","isbn10","title_and_subtitle","tagged_description", "anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"], axis=1, inplace=True)

# %%
dataset.sample()
# Out:
#                     title         authors categories  \
# 3676  Wizard's First Rule  Terry Goodkind    Fiction
#
#                                               thumbnail  \
# 3676  http://books.google.com/books/content?id=fdpKP...
#
#                                             description  published_year  \
# 3676  The masterpiece that started The New York Time...          2003.0
#
#       average_rating  num_pages  ratings_count simple_categories
# 3676            4.14      836.0       197049.0           Fiction

# %%
dataset.drop(["average_rating","ratings_count","categories"], axis=1, inplace=True)

# %%
dataset
# Out:
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5225                                  Mistaken Identity
# 5226                                Journey to the East
# 5227  The Monk Who Sold His Ferrari: A Fable About F...
# 5228                                          I Am that
# 5229                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# ...

# %%
dataset.to_csv("book.csv", index=False)
